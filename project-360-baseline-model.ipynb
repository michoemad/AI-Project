# %%
import csv
import numpy as np
import random
import pandas as pd
from collections import Counter
import json

# %%
def init_stop_words():
    # Parsing stop words
    file = open('stop_words_english.json', 'r', encoding='utf-8')
    data = file.read()
    stop_words = json.loads(data)

    return stop_words

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
class BaselineModel():
    def __init__(self):
        super(BaselineModel, self).__init__()
        self.rep_multipler = {}
        self.demo_multipler = {}

# %%
def train(model, batch_size, num_common_words):
    header = ['tweet', 'id', 'conversation_id', 'party']
    train_df = pd.read_csv(
        "train_set.csv",
        names=header,
        index_col=False,
        error_bad_lines = False)

    rep_counter = Counter()
    demo_counter = Counter()

    # Excluding headers from list of tweet
    tweet_list = train_df.values.tolist()

    # Dividing list of tweets into batches 
    num_batches = 0
    tweet_batch = list(chunks(tweet_list[0:30000], batch_size))
    total_batches = len(tweet_batch)

    for batch in tweet_batch:
        for tweet in batch:
            # Replacing Typesetter's apostrophe with Typewriter apostrophe
            sentence = tweet[0].lower().replace("’", "'").split()
            
            if tweet[3] == "R":
                rep_counter = rep_counter + Counter(sentence)
            elif tweet[3] == "D":
                demo_counter = demo_counter + Counter(sentence)
        num_batches += 1
        print("Training Progression: {:0.2f}%".format((num_batches/total_batches)*100))


    stop_words = init_stop_words()

    # Exclude stop words from analysis
    for word in stop_words:
        if word in rep_counter:
            del rep_counter[word]
        
        if word in demo_counter:
            del demo_counter[word]

    # Only focus on the top 20 most common words
    rep_common_words = rep_counter.most_common(num_common_words)
    demo_common_words = demo_counter.most_common(num_common_words)

    rep_total_words = 0
    demo_total_words = 0

    for word in rep_common_words:
        rep_total_words += word[1]
        
    for word in demo_common_words:
        demo_total_words += word[1]

    # Assign multipler scores to each word
    rep_multipler = {}
    demo_multipler = {}

    for word in rep_common_words:
        rep_multipler[word[0]] = word[1]/rep_total_words
        
    for word in demo_common_words:
        demo_multipler[word[0]] = word[1]/demo_total_words

    model.rep_multipler = rep_multipler
    model.demo_multipler = demo_multipler

# %%
model = BaselineModel()
train(model, 1000, 150)
# Out:
# c:\Users\Nate\Documents\School\Winter 2021\APS360\AI-Project\env\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Training Progression: 3.33%
# Training Progression: 6.67%
# Training Progression: 10.00%
# Training Progression: 13.33%
# Training Progression: 16.67%
# Training Progression: 20.00%
# Training Progression: 23.33%
# Training Progression: 26.67%
# Training Progression: 30.00%
# Training Progression: 33.33%
# Training Progression: 36.67%
# Training Progression: 40.00%
# Training Progression: 43.33%
# Training Progression: 46.67%
# Training Progression: 50.00%
# Training Progression: 53.33%
# Training Progression: 56.67%
# Training Progression: 60.00%
# Training Progression: 63.33%
# Training Progression: 66.67%
# Training Progression: 70.00%
# Training Progression: 73.33%
# Training Progression: 76.67%
# Training Progression: 80.00%
# Training Progression: 83.33%
# Training Progression: 86.67%
# Training Progression: 90.00%
# Training Progression: 93.33%
# Training Progression: 96.67%
# Training Progression: 100.00%

# %%
def test(model, batch_size):
    header = ['tweet', 'id', 'conversation_id', 'party']
    test_df = pd.read_csv(
        "test_set.csv",
        names=header,
        index_col=False,
        error_bad_lines = False)

    # Excluding headers from list of tweet
    tweet_list = test_df.values.tolist()

    rep_multipler = model.rep_multipler
    demo_multipler = model.demo_multipler

    # Dividing list of tweets into batches 
    num_batches = 0
    tweet_batch = list(chunks(tweet_list, batch_size))
    total_batches = len(tweet_batch)

    test_acc = []

    acc = 0
    total = 0
    unclassified_tweets = 0

    for batch in tweet_batch:
        for tweet in batch:
            # Replacing Typesetter's apostrophe with Typewriter apostrophe
            sentence = tweet[0].lower().replace("’", "'").split()

            party = None
            rep_score = 0
            demo_score = 0

            for word in sentence:
                if word in rep_multipler:
                    rep_score += rep_multipler[word]
                if word in demo_multipler: 
                    demo_score += demo_multipler[word]

            if rep_score > demo_score:
                party = "R"
            elif rep_score < demo_score: 
                party = "D"
            else:
                party = "unclassified"
                unclassified_tweets += 1

            acc += int(tweet[3] == party)
            total += 1

        num_batches += 1
        print("Testing Progression: {:0.2f}%".format((num_batches/total_batches)*100))
        test_acc.append(acc/total)

    print("\n\nTest Accuracy assuming unclassified tweets are all incorrect: {:0.2f}%".format(test_acc[-1]*100))
    # print("Number of unclassified tweets: {}".format(unclassified_tweets))
    acc += unclassified_tweets/2

    test_acc.append(acc/total)

    print("Final Test Accuracy assuming half of the unclassified tweets are correctly classified: {:0.2f}%".format(test_acc[-1]*100))

# %%
test(model, 1000)
# Out:
# Testing Progression: 0.40%
# Testing Progression: 0.80%
# Testing Progression: 1.20%
# Testing Progression: 1.61%
# Testing Progression: 2.01%
# Testing Progression: 2.41%
# Testing Progression: 2.81%
# Testing Progression: 3.21%
# Testing Progression: 3.61%
# Testing Progression: 4.02%
# Testing Progression: 4.42%
# Testing Progression: 4.82%
# Testing Progression: 5.22%
# Testing Progression: 5.62%
# Testing Progression: 6.02%
# Testing Progression: 6.43%
# Testing Progression: 6.83%
# Testing Progression: 7.23%
# Testing Progression: 7.63%
# Testing Progression: 8.03%
# Testing Progression: 8.43%
# Testing Progression: 8.84%
# Testing Progression: 9.24%
# Testing Progression: 9.64%
# Testing Progression: 10.04%
# Testing Progression: 10.44%
# Testing Progression: 10.84%
# Testing Progression: 11.24%
# Testing Progression: 11.65%
# Testing Progression: 12.05%
# Testing Progression: 12.45%
# Testing Progression: 12.85%
# Testing Progression: 13.25%
# Testing Progression: 13.65%
# Testing Progression: 14.06%
# Testing Progression: 14.46%
# Testing Progression: 14.86%
# Testing Progression: 15.26%
# Testing Progression: 15.66%
# Testing Progression: 16.06%
# Testing Progression: 16.47%
# Testing Progression: 16.87%
# Testing Progression: 17.27%
# Testing Progression: 17.67%
# Testing Progression: 18.07%
# Testing Progression: 18.47%
# Testing Progression: 18.88%
# Testing Progression: 19.28%
# Testing Progression: 19.68%
# Testing Progression: 20.08%
# Testing Progression: 20.48%
# Testing Progression: 20.88%
# Testing Progression: 21.29%
# Testing Progression: 21.69%
# Testing Progression: 22.09%
# Testing Progression: 22.49%
# Testing Progression: 22.89%
# Testing Progression: 23.29%
# Testing Progression: 23.69%
# Testing Progression: 24.10%
# Testing Progression: 24.50%
# Testing Progression: 24.90%
# Testing Progression: 25.30%
# Testing Progression: 25.70%
# Testing Progression: 26.10%
# Testing Progression: 26.51%
# Testing Progression: 26.91%
# Testing Progression: 27.31%
# Testing Progression: 27.71%
# Testing Progression: 28.11%
# Testing Progression: 28.51%
# Testing Progression: 28.92%
# Testing Progression: 29.32%
# Testing Progression: 29.72%
# Testing Progression: 30.12%
# Testing Progression: 30.52%
# Testing Progression: 30.92%
# Testing Progression: 31.33%
# Testing Progression: 31.73%
# Testing Progression: 32.13%
# Testing Progression: 32.53%
# Testing Progression: 32.93%
# Testing Progression: 33.33%
# Testing Progression: 33.73%
# Testing Progression: 34.14%
# Testing Progression: 34.54%
# Testing Progression: 34.94%
# Testing Progression: 35.34%
# Testing Progression: 35.74%
# Testing Progression: 36.14%
# Testing Progression: 36.55%
# Testing Progression: 36.95%
# Testing Progression: 37.35%
# Testing Progression: 37.75%
# Testing Progression: 38.15%
# Testing Progression: 38.55%
# Testing Progression: 38.96%
# Testing Progression: 39.36%
# Testing Progression: 39.76%
# Testing Progression: 40.16%
# Testing Progression: 40.56%
# Testing Progression: 40.96%
# Testing Progression: 41.37%
# Testing Progression: 41.77%
# Testing Progression: 42.17%
# Testing Progression: 42.57%
# Testing Progression: 42.97%
# Testing Progression: 43.37%
# Testing Progression: 43.78%
# Testing Progression: 44.18%
# Testing Progression: 44.58%
# Testing Progression: 44.98%
# Testing Progression: 45.38%
# Testing Progression: 45.78%
# Testing Progression: 46.18%
# Testing Progression: 46.59%
# Testing Progression: 46.99%
# Testing Progression: 47.39%
# Testing Progression: 47.79%
# Testing Progression: 48.19%
# Testing Progression: 48.59%
# Testing Progression: 49.00%
# Testing Progression: 49.40%
# Testing Progression: 49.80%
# Testing Progression: 50.20%
# Testing Progression: 50.60%
# Testing Progression: 51.00%
# Testing Progression: 51.41%
# Testing Progression: 51.81%
# Testing Progression: 52.21%
# Testing Progression: 52.61%
# Testing Progression: 53.01%
# Testing Progression: 53.41%
# Testing Progression: 53.82%
# Testing Progression: 54.22%
# Testing Progression: 54.62%
# Testing Progression: 55.02%
# Testing Progression: 55.42%
# Testing Progression: 55.82%
# Testing Progression: 56.22%
# Testing Progression: 56.63%
# Testing Progression: 57.03%
# Testing Progression: 57.43%
# Testing Progression: 57.83%
# Testing Progression: 58.23%
# Testing Progression: 58.63%
# Testing Progression: 59.04%
# Testing Progression: 59.44%
# Testing Progression: 59.84%
# Testing Progression: 60.24%
# Testing Progression: 60.64%
# Testing Progression: 61.04%
# Testing Progression: 61.45%
# Testing Progression: 61.85%
# Testing Progression: 62.25%
# Testing Progression: 62.65%
# Testing Progression: 63.05%
# Testing Progression: 63.45%
# Testing Progression: 63.86%
# Testing Progression: 64.26%
# Testing Progression: 64.66%
# Testing Progression: 65.06%
# Testing Progression: 65.46%
# Testing Progression: 65.86%
# Testing Progression: 66.27%
# Testing Progression: 66.67%
# Testing Progression: 67.07%
# Testing Progression: 67.47%
# Testing Progression: 67.87%
# Testing Progression: 68.27%
# Testing Progression: 68.67%
# Testing Progression: 69.08%
# Testing Progression: 69.48%
# Testing Progression: 69.88%
# Testing Progression: 70.28%
# Testing Progression: 70.68%
# Testing Progression: 71.08%
# Testing Progression: 71.49%
# Testing Progression: 71.89%
# Testing Progression: 72.29%
# Testing Progression: 72.69%
# Testing Progression: 73.09%
# Testing Progression: 73.49%
# Testing Progression: 73.90%
# Testing Progression: 74.30%
# Testing Progression: 74.70%
# Testing Progression: 75.10%
# Testing Progression: 75.50%
# Testing Progression: 75.90%
# Testing Progression: 76.31%
# Testing Progression: 76.71%
# Testing Progression: 77.11%
# Testing Progression: 77.51%
# Testing Progression: 77.91%
# Testing Progression: 78.31%
# Testing Progression: 78.71%
# Testing Progression: 79.12%
# Testing Progression: 79.52%
# Testing Progression: 79.92%
# Testing Progression: 80.32%
# Testing Progression: 80.72%
# Testing Progression: 81.12%
# Testing Progression: 81.53%
# Testing Progression: 81.93%
# Testing Progression: 82.33%
# Testing Progression: 82.73%
# Testing Progression: 83.13%
# Testing Progression: 83.53%
# Testing Progression: 83.94%
# Testing Progression: 84.34%
# Testing Progression: 84.74%
# Testing Progression: 85.14%
# Testing Progression: 85.54%
# Testing Progression: 85.94%
# Testing Progression: 86.35%
# Testing Progression: 86.75%
# Testing Progression: 87.15%
# Testing Progression: 87.55%
# Testing Progression: 87.95%
# Testing Progression: 88.35%
# Testing Progression: 88.76%
# Testing Progression: 89.16%
# Testing Progression: 89.56%
# Testing Progression: 89.96%
# Testing Progression: 90.36%
# Testing Progression: 90.76%
# Testing Progression: 91.16%
# Testing Progression: 91.57%
# Testing Progression: 91.97%
# Testing Progression: 92.37%
# Testing Progression: 92.77%
# Testing Progression: 93.17%
# Testing Progression: 93.57%
# Testing Progression: 93.98%
# Testing Progression: 94.38%
# Testing Progression: 94.78%
# Testing Progression: 95.18%
# Testing Progression: 95.58%
# Testing Progression: 95.98%
# Testing Progression: 96.39%
# Testing Progression: 96.79%
# Testing Progression: 97.19%
# Testing Progression: 97.59%
# Testing Progression: 97.99%
# Testing Progression: 98.39%
# Testing Progression: 98.80%
# Testing Progression: 99.20%
# Testing Progression: 99.60%
# Testing Progression: 100.00%
#
#
# Test Accuracy assuming unclassified tweets are all incorrect: 47.13%
# Final Test Accuracy assuming half of the unclassified tweets are correctly classified: 58.08%
